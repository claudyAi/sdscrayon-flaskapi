# %%
from osgeo import gdal as GD  
import matplotlib.pyplot as plt 
import numpy as np

# %%
code = 2

vali = GD.Open(f'./outputCCIresized/k_{code}_2017_agbm.tif')
data_set = GD.Open(f'./sent2_8bandsresized/S_k_{code}_2017.tif')

# %%
band_vali = vali.GetRasterBand(1)

band_1 = data_set.GetRasterBand(1)
band_2 = data_set.GetRasterBand(2)
band_3 = data_set.GetRasterBand(3)
band_4 = data_set.GetRasterBand(4)
band_5 = data_set.GetRasterBand(5)
band_6 = data_set.GetRasterBand(6)
band_7 = data_set.GetRasterBand(7)
band_8 = data_set.GetRasterBand(8)
band_9 = data_set.GetRasterBand(9)
band_10 = data_set.GetRasterBand(10)
band_11 = data_set.GetRasterBand(11)

# %%
bvali = band_vali.ReadAsArray()  

b1 = band_1.ReadAsArray()  
b2 = band_2.ReadAsArray()  
b3 = band_3.ReadAsArray()  
b4 = band_4.ReadAsArray()  
b5 = band_5.ReadAsArray()  
b6 = band_6.ReadAsArray()  
b7 = band_7.ReadAsArray()  
b8 = band_8.ReadAsArray()  
b9 = band_9.ReadAsArray()  
b10 = band_10.ReadAsArray()  
b11 = band_11.ReadAsArray()

# %%
img = np.dstack((b1, b2, b3))  
f = plt.figure() 
ax1 = f.add_subplot(2,2,1)
ax1.imshow(b1) 
ax2 = f.add_subplot(2,2,2)
ax2.imshow(bvali) 
# plt.savefig('Tiff.png') 
plt.show()
